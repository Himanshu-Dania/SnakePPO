# %%
# !pip install stable_baselines3
# !pip install gym
# !pip install pygame
# !pip install shimmy>=0.2.1
from stable_baselines3 import PPO, A2C
# from pygame_recorder import ScreenRecorder
import gym 
import pygame
import numpy as np
import random
import sys
from gym import spaces
# Out:
# Requirement already satisfied: stable_baselines3 in c:\users\krish\anaconda3\lib\site-packages (2.1.0)
# Requirement already satisfied: gymnasium<0.30,>=0.28.1 in c:\users\krish\anaconda3\lib\site-packages (from stable_baselines3) (0.29.1)
# Requirement already satisfied: numpy>=1.20 in c:\users\krish\anaconda3\lib\site-packages (from stable_baselines3) (1.24.3)
# Requirement already satisfied: torch>=1.13 in c:\users\krish\anaconda3\lib\site-packages (from stable_baselines3) (2.1.0)
# Requirement already satisfied: cloudpickle in c:\users\krish\anaconda3\lib\site-packages (from stable_baselines3) (2.2.1)
# Requirement already satisfied: pandas in c:\users\krish\anaconda3\lib\site-packages (from stable_baselines3) (2.0.3)
# Requirement already satisfied: matplotlib in c:\users\krish\anaconda3\lib\site-packages (from stable_baselines3) (3.7.2)
# Requirement already satisfied: typing-extensions>=4.3.0 in c:\users\krish\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (4.7.1)
# Requirement already satisfied: farama-notifications>=0.0.1 in c:\users\krish\anaconda3\lib\site-packages (from gymnasium<0.30,>=0.28.1->stable_baselines3) (0.0.4)
# Requirement already satisfied: filelock in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3) (3.9.0)
# Requirement already satisfied: sympy in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3) (1.11.1)
# Requirement already satisfied: networkx in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3) (3.1)
# Requirement already satisfied: jinja2 in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3) (3.1.2)
# Requirement already satisfied: fsspec in c:\users\krish\anaconda3\lib\site-packages (from torch>=1.13->stable_baselines3) (2023.4.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (9.4.0)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\krish\anaconda3\lib\site-packages (from matplotlib->stable_baselines3) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\krish\anaconda3\lib\site-packages (from pandas->stable_baselines3) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\users\krish\anaconda3\lib\site-packages (from pandas->stable_baselines3) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\krish\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib->stable_baselines3) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\krish\anaconda3\lib\site-packages (from jinja2->torch>=1.13->stable_baselines3) (2.1.1)
# Requirement already satisfied: mpmath>=0.19 in c:\users\krish\anaconda3\lib\site-packages (from sympy->torch>=1.13->stable_baselines3) (1.3.0)
# Requirement already satisfied: gym in c:\users\krish\anaconda3\lib\site-packages (0.26.2)
# Requirement already satisfied: numpy>=1.18.0 in c:\users\krish\anaconda3\lib\site-packages (from gym) (1.24.3)
# Requirement already satisfied: cloudpickle>=1.2.0 in c:\users\krish\anaconda3\lib\site-packages (from gym) (2.2.1)
# Requirement already satisfied: gym-notices>=0.0.4 in c:\users\krish\anaconda3\lib\site-packages (from gym) (0.0.8)

# %%
class SnakeEnv(gym.Env):
  """Custom Environment that follows gym interface"""
  metadata = {'render.modes': ['human']}
  difficulty = 10
  frame_size_x = 600
  frame_size_y = 400
  black = pygame.Color(0, 0, 0)
  white = pygame.Color(255, 255, 255)
  red = pygame.Color(255, 0, 0)
  green = pygame.Color(0, 255, 0)
  blue = pygame.Color(0, 0, 255)
  LEFT = 0
  RIGHT = 1
  UP = 2
  DOWN = 3
  def __init__(self):
    super(SnakeEnv, self).__init__()
    pygame.init()
    pygame.display.set_caption('Snake Eater')
    self.fps_controller = pygame.time.Clock()
    self.game_window = pygame.display.set_mode((self.frame_size_x, self.frame_size_y))
    
    
    
    self.prev_snake_pos = [100, 50]
    self.snake_pos = [100, 50]
    self.snake_body = [[100, 50], [100 - 10, 50], [100 - (2 * 10), 50]]

    self.food_spawn = True
    self.food_pos = [random.randrange(1, (self.frame_size_x // 10)) * 10, random.randrange(1, (self.frame_size_y // 10)) * 10]
    

    self.direction = 'RIGHT' #starting dir
    self.change_to = self.direction
    self.counter = 0
    self.score = 0
    self.game_over = False
    number_of_actions = 4 #udlr
    number_of_observations = 4 #snake pos(x,y), food pos(x,y)
    self.action_space = spaces.Discrete(number_of_actions)
    self.observation_space = spaces.Box(low=-np.inf, high=np.inf, shape=(number_of_observations,), dtype=np.float32)

  def step(self, action):
      self.counter += 1
      if self.counter > 100:#timeout for snakes looping
          return np.array([self.snake_pos[0], self.snake_pos[1], self.food_pos[0], self.food_pos[1]], dtype=np.float32), -100, True, {}
      #new dir
      if action == self.UP:
          self.change_to = 'UP'
      if action == self.DOWN:
          self.change_to = 'DOWN'
      if action == self.LEFT:
          self.change_to = 'LEFT'
      if action == self.RIGHT:
          self.change_to = 'RIGHT'
    #cant rotate 180 degrees
      if self.change_to == 'UP' and self.direction != 'DOWN':
          self.direction = 'UP'
      if self.change_to == 'DOWN' and self.direction != 'UP':
          self.direction = 'DOWN'
      if self.change_to == 'LEFT' and self.direction != 'RIGHT':
          self.direction = 'LEFT'
      if self.change_to == 'RIGHT' and self.direction != 'LEFT':
          self.direction = 'RIGHT'
      if self.direction == 'UP':
          self.snake_pos[1] -= 10
      if self.direction == 'DOWN':
          self.snake_pos[1] += 10
      if self.direction == 'LEFT':
          self.snake_pos[0] -= 10
      if self.direction == 'RIGHT':
          self.snake_pos[0] += 10
      #eats food
      self.snake_body.insert(0, list(self.snake_pos))
      if self.snake_pos[0] == self.food_pos[0] and self.snake_pos[1] == self.food_pos[1]:
          self.counter = 0
          self.score += 1
          self.food_spawn = False
      else:
          self.snake_body.pop()
      if not self.food_spawn:
          self.food_pos = [random.randrange(1, (self.frame_size_x // 10)) * 10, random.randrange(1, (self.frame_size_y // 10)) * 10]
      self.food_spawn = True
      #goes outside screen
      if self.snake_pos[0] < 0 or self.snake_pos[0] > self.frame_size_x - 10:
          self.game_over = True
      if self.snake_pos[1] < 0 or self.snake_pos[1] > self.frame_size_y - 10:
          self.game_over = True
    #hits itself
      for block in self.snake_body[1:]:
          if self.snake_pos[0] == block[0] and self.snake_pos[1] == block[1]:
              self.game_over = True
      reward = 0
    #gets food
      if self.snake_pos[0] == self.food_pos[0] and self.snake_pos[1] == self.food_pos[1]:
          reward = 100
        #far from food
      elif abs(self.snake_pos[0] - self.food_pos[0]) + abs(self.snake_pos[1] - self.food_pos[1]) > abs(self.prev_snake_pos[0] - self.food_pos[0]) + abs(self.prev_snake_pos[1] - self.food_pos[1]):
          reward = -1
        #near food
      elif abs(self.snake_pos[0] - self.food_pos[0]) + abs(self.snake_pos[1] - self.food_pos[1]) < abs(self.prev_snake_pos[0] - self.food_pos[0]) + abs(self.prev_snake_pos[1] - self.food_pos[1]):
          reward = 1
      self.prev_snake_pos = self.snake_pos.copy()
      done = self.game_over
      info = {}
      # obs, reward, done,info
      return np.array([self.snake_pos[0], self.snake_pos[1], self.food_pos[0], self.food_pos[1]], dtype=np.float32), reward, done, info
  def reset(self):
        #reset params
      self.snake_pos = [100, 50]
      self.prev_snake_pos = [100, 50]
      self.snake_body = [[100, 50], [100 - 10, 50], [100 - (2 * 10), 50]]
      self.counter = 0
      self.food_pos = [random.randrange(1, (self.frame_size_x // 10)) * 10,
                       random.randrange(1, (self.frame_size_y // 10)) * 10]
      self.food_spawn = True

      self.direction = 'RIGHT'
      self.change_to = self.direction

      self.score = 0
      self.game_over = False
      return np.array([self.snake_pos[0], self.snake_pos[1], self.food_pos[0], self.food_pos[1]], dtype=np.float32)  # reward, done, info can't be included
  def render(self, mode='human'):
        #render through pygame window(buggy)
      self.game_window.fill(self.black)
      for pos in self.snake_body:
          
          pygame.draw.rect(self.game_window, self.green, pygame.Rect(pos[0], pos[1], 10, 10))

      pygame.draw.rect(self.game_window, self.white, pygame.Rect(self.food_pos[0], self.food_pos[1], 10, 10))
      self.show_score(1, self.white, 'consolas', 20)
     
      pygame.display.update()
      self.fps_controller.tick(self.difficulty)
  def close (self):
    #exit
      pygame.quit()
      sys.exit()

  def show_score(self, choice, color, font, size):
    #score for showing score
      score_font = pygame.font.SysFont(font, size)
      score_surface = score_font.render('Score : ' + str(self.score), True, color)
      score_rect = score_surface.get_rect()
      if choice == 1:
          score_rect.midtop = (self.frame_size_x / 10, 15)
      else:
          score_rect.midtop = (self.frame_size_x / 2, self.frame_size_y / 1.25)
      self.game_window.blit(score_surface, score_rect)

# %%
#create model
env = SnakeEnv()
model = PPO('MlpPolicy', env, verbose=1)
# model.learn(total_timesteps=100000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.

# %%
#reload trained model and test
model=PPO.load("snake_ai_model_PPO_500000")
obs = env.reset()
env.render()
for i in range(500):
    action, _state = model.predict(obs, deterministic=True)
    obs, reward, done, info = env.step(action)
    env.render()
    if done:
      obs = env.reset()
pygame.quit()
